# %% [markdown]
# # Just Value New Orleans Gentrification Analysis
# Trey Briggs 05/17/2023 6:30PM EST

# %%
import os 
os.chdir('C:/Users/brigg/Documents/JupyterNotebooks/JustValue')
# Load Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import folium
from zipfile import ZipFile 
from io import BytesIO
import requests
import json
import dotenv

# %% [markdown]
# For this assignment, I will be using

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# ### US Census Dataset

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
# Map variable names to their respective indices in the response
variable_mapping = {
    'B19013_001E': 'median_income',
    'B25064_001E': 'median_rent',
    'B01001_001E': 'total_pop',
    'B01001H_008E': 'male_white_20_24',
    'B01001H_009E': 'male_white_25_29',
    'B01001H_010E': 'male_white_30_34',
    'B01001H_023E': 'female_white_20_24',
    'B01001H_024E': 'female_white_25_29',
    'B01001H_025E': 'female_white_30_34',
}

# %%
# Pull variables from already created map for API request
variables = variable_mapping.keys()
variables_string = ','.join(variables)
variables_string
# Out:
# 'B19013_001E,B25064_001E,B01001_001E,B01001H_008E,B01001H_009E,B01001H_010E,B01001H_023E,B01001H_024E,B01001H_025E'

# %%
# Construct the API request URL
base_url = "https://api.census.gov/data"
endpoint = "/{year}/acs/acs5"
census_key = os.getenv('census_key') # API key security

# Specify the variables and geographic area
variables = variables_string  # Vars
state = "22"  # Louisiana's FIPS code
county = "071"  # Orleans Parish's FIPS code
in_metropolitan_statistical_area = "35380"  # New Orleans-Metairie, LA Metro Area's CBSA code

# Define the range of years
start_year = 2013
end_year = 2021


census_df = pd.DataFrame()

# Loop through each year and make API requests
for year in range(start_year, end_year + 1):
    # Construct the request URL
    url = f"{base_url}{endpoint.format(year=year)}"
    params = {
        "get": variables,
        "for": "tract:*",
        "in" : "state:22 county:071",
        "key": census_key,
    }

    # Make the API request
    response = requests.get(url, params=params)

    # Process the response
    if response.status_code == 200:
        # Process and work with the data as needed for each year
        data = response.json()
        
        temp_df = pd.DataFrame(data[1:], columns=data[0])
        temp_df['year'] = year
        
        census_df = census_df.append(temp_df)
    else:
        print("Error:", response.text)
        print(url)

# Reset the index of the resulting DataFrame
census_df.reset_index(drop=True, inplace=True)

variable_mapping = {
    'B19013_001E': 'median_income',
    'B25064_001E': 'median_rent',
    'B01001_001E': 'total_pop',
    'B01001H_008E': 'male_white_20_24',
    'B01001H_009E': 'male_white_25_29',
    'B01001H_010E': 'male_white_30_34',
    'B01001H_023E': 'female_white_20_24',
    'B01001H_024E': 'female_white_25_29',
    'B01001H_025E': 'female_white_30_34',
    'state':'state',
    'county':'county',
}

#rename the column data frames
census_df.rename(columns=variable_mapping, inplace=True)

# Display the resulting DataFrame
census_df.head()
# Out:
# C:\Users\brigg\AppData\Local\Temp\ipykernel_27576\113462738.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   census_df = census_df.append(temp_df)
# C:\Users\brigg\AppData\Local\Temp\ipykernel_27576\113462738.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   census_df = census_df.append(temp_df)
# C:\Users\brigg\AppData\Local\Temp\ipykernel_27576\113462738.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   census_df = census_df.append(temp_df)
# C:\Users\brigg\AppData\Local\Temp\ipykernel_27576\113462738.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   census_df = census_df.append(temp_df)
# C:\Users\brigg\AppData\Local\Temp\ipykernel_27576\113462738.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   census_df = census_df.append(temp_df)
# C:\Users\brigg\AppData\Local\Temp\ipykernel_27576\113462738.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   census_df = census_df.append(temp_df)
# C:\Users\brigg\AppData\Local\Temp\ipykernel_27576\113462738.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   census_df = census_df.append(temp_df)
# C:\Users\brigg\AppData\Local\Temp\ipykernel_27576\113462738.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   census_df = census_df.append(temp_df)
# C:\Users\brigg\AppData\Local\Temp\ipykernel_27576\113462738.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   census_df = census_df.append(temp_df)
#   median_income median_rent total_pop male_white_20_24 male_white_25_29  \
# 0         86182        1023      1904               15              101
# 1         51477         971      1675               32               98
# 2         65236        1271      2120               45              144
# 3         46875        1011      1232               14               34
# 4         81406        1433      1315               48               33
#
#   male_white_30_34 female_white_20_24 female_white_25_29 female_white_30_34  \
# 0               35                 23                 49                 44
# 1               12                127                 47                 80
# 2               95                 63                176                 53
# 3               62                  3                 64                 57
# 4               85                 49                 91                 38
#
#   state county   tract  year
# 0    22    071  009000  2013
# 1    22    071  009600  2013
# 2    22    071  010100  2013
# 3    22    071  010600  2013
# 4    22    071  011500  2013

# %%
#remove columsn where total pop is zero
census_df.total_pop = census_df.total_pop.astype(int)
census_df = census_df.loc[census_df['total_pop'] != 0]

# %%
#minor data cleansing needed at this point
census_df2 = census_df

start_col = 'median_income'
end_col = 'female_white_30_34'
census_df2.loc[:, start_col:end_col] = census_df2.loc[:, start_col:end_col].apply(pd.to_numeric, errors='coerce').astype(int)

#sum columns and divide by total to get the prop target used in our index
start_col = 'male_white_20_24'
end_col = 'female_white_30_34'
census_df2['prop_white_20_34'] = census_df2.loc[:, start_col:end_col].sum(axis=1)/census_df2.total_pop


#convert to string
census_df2.state = census_df2.state.astype(str)
census_df2.county = census_df2.county.astype(str)
census_df2.tract = census_df2.tract.astype(str)

#join to creat 11 digit fips code for matching
census_df2['TRACT'] = census_df2['state'].str.cat([census_df2['county'], census_df2['tract']], sep='')
census_df2 = census_df2.drop(['state', 'county', 'tract'], axis = 1)

census_df2.head()
# Out:
#    median_income  median_rent  total_pop  male_white_20_24  male_white_25_29  \
# 0          86182         1023       1904                15               101
# 1          51477          971       1675                32                98
# 2          65236         1271       2120                45               144
# 3          46875         1011       1232                14                34
# 4          81406         1433       1315                48                33
#
#    male_white_30_34  female_white_20_24  female_white_25_29  \
# 0                35                  23                  49
# 1                12                 127                  47
# 2                95                  63                 176
# 3                62                   3                  64
# 4                85                  49                  91
#
#    female_white_30_34  year  prop_white_20_34        TRACT
# 0                  44  2013          0.140231  22071009000
# 1                  80  2013          0.236418  22071009600
# 2                  53  2013          0.271698  22071010100
# 3                  57  2013          0.189935  22071010600
# 4                  38  2013          0.261597  22071011500

# %%
#We will match on these tracts later
tracts = census_df2.TRACT.unique()

# %%
# Filter out string columns
numeric_cols = census_df2.select_dtypes(exclude='object').columns
numeric_cols
census_df2.TRACT = census_df2.TRACT.astype(np.int64)
# Out:
# Index(['median_income', 'median_rent', 'total_pop', 'male_white_20_24',
#        'male_white_25_29', 'male_white_30_34', 'female_white_20_24',
#        'female_white_25_29', 'female_white_30_34', 'year', 'prop_white_20_34'],
#       dtype='object')

# %%
census_df2 = census_df2.loc[(census_df2[numeric_cols] >= 0).all(axis=1)]

# %%
census_df2
# Out:
#       median_income  median_rent  total_pop  male_white_20_24  \
# 0             86182         1023       1904                15
# 1             51477          971       1675                32
# 2             65236         1271       2120                45
# 3             46875         1011       1232                14
# 4             81406         1433       1315                48
# ...             ...          ...        ...               ...
# 1598          45119          888       1608                 0
# 1599          36645         1087        992                 0
# 1600          99063         1347       1748                 2
# 1601          18611          816       1778                 6
# 1602          88992         1315       1583                 8
#
#       male_white_25_29  male_white_30_34  female_white_20_24  \
# 0                  101                35                  23
# 1                   98                12                 127
# 2                  144                95                  63
# 3                   34                62                   3
# 4                   33                85                  49
# ...                ...               ...                 ...
# 1598                25                 7                   9
# 1599                38                13                   7
# 1600                20                41                   3
# 1601                 5                 5                   0
# 1602                25                79                   2
#
#       female_white_25_29  female_white_30_34  year  prop_white_20_34  \
# 0                     49                  44  2013          0.140231
# 1                     47                  80  2013          0.236418
# 2                    176                  53  2013          0.271698
# 3                     64                  57  2013          0.189935
# 4                     91                  38  2013          0.261597
# ...                  ...                 ...   ...               ...
# 1598                   5                   0  2021          0.028607
# 1599                  22                   0  2021          0.080645
# 1600                  70                  99  2021          0.134439
# 1601                   9                   5  2021          0.016873
# 1602                  38                  88  2021          0.151611
#
#             TRACT
# 0     22071009000
# 1     22071009600
# 2     22071010100
# 3     22071010600
# 4     22071011500
# ...           ...
# 1598  22071014101
# 1599  22071014102
# 1600  22071014200
# 1601  22071014300
# 1602  22071014400
#
# [1526 rows x 12 columns]

# %% [markdown]
# ### FHFA Dataset|

# %%
# Load fhfa dataset
fhfa_path = 'https://www.fhfa.gov/DataTools/Documents/UAD-Data-Files/UADAggs_tract.zip'

# by default pandas uses zip as compression
fhfa_df = pd.read_csv(fhfa_path)
fhfa_df.head()
# Out:
#   SOURCE               SERIES SERIESID  FREQUENCY GEOLEVEL  GEONAME  \
# 0    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 1    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 2    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 3    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 4    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
#
#   STATEPOSTAL  STATEFIPS  FIPS       TRACT  METRO    PURPOSE  YEAR  QUARTER  \
# 0          AL          1  1001  1001020100    NaN   Purchase  2013        5
# 1          AL          1  1001  1001020100    NaN  Refinance  2013        5
# 2          AL          1  1001  1001020100    NaN       Both  2013        5
# 3          AL          1  1001  1001020100    NaN   Purchase  2014        5
# 4          AL          1  1001  1001020100    NaN  Refinance  2014        5
#
#       CHARACTERISTIC        category  SUPPRESSED  VALUE
# 0  No Characteristic  All Appraisals           1    NaN
# 1  No Characteristic  All Appraisals           1    NaN
# 2  No Characteristic  All Appraisals           0   16.0
# 3  No Characteristic  All Appraisals           1    NaN
# 4  No Characteristic  All Appraisals           1    NaN

# %%
#select Lousiana
fhfa_LA_df = fhfa_df.query("STATEFIPS==22")

fhfa_LA_df.head()
# Out:
#        SOURCE               SERIES SERIESID  FREQUENCY GEOLEVEL  GEONAME  \
# 933356    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 933357    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 933358    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 933359    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 933360    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
#
#        STATEPOSTAL  STATEFIPS   FIPS        TRACT  METRO    PURPOSE  YEAR  \
# 933356          LA         22  22001  22001960101    NaN   Purchase  2013
# 933357          LA         22  22001  22001960101    NaN  Refinance  2013
# 933358          LA         22  22001  22001960101    NaN       Both  2013
# 933359          LA         22  22001  22001960101    NaN   Purchase  2014
# 933360          LA         22  22001  22001960101    NaN  Refinance  2014
#
#         QUARTER     CHARACTERISTIC        category  SUPPRESSED  VALUE
# 933356        5  No Characteristic  All Appraisals           1    NaN
# 933357        5  No Characteristic  All Appraisals           1    NaN
# 933358        5  No Characteristic  All Appraisals           0   16.0
# 933359        5  No Characteristic  All Appraisals           1    NaN
# 933360        5  No Characteristic  All Appraisals           1    NaN

# %%
#select New Orleans 
fhfa_LA_df = fhfa_LA_df.query("PURPOSE =='Both'")
fhfa_LA_df.head()
# Out:
#        SOURCE               SERIES SERIESID  FREQUENCY GEOLEVEL  GEONAME  \
# 933358    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 933361    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 933364    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 933367    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
# 933370    UAD  Count of Appraisals    COUNT  Quarterly    Tract      NaN
#
#        STATEPOSTAL  STATEFIPS   FIPS        TRACT  METRO PURPOSE  YEAR  \
# 933358          LA         22  22001  22001960101    NaN    Both  2013
# 933361          LA         22  22001  22001960101    NaN    Both  2014
# 933364          LA         22  22001  22001960101    NaN    Both  2015
# 933367          LA         22  22001  22001960101    NaN    Both  2016
# 933370          LA         22  22001  22001960101    NaN    Both  2017
#
#         QUARTER     CHARACTERISTIC        category  SUPPRESSED  VALUE
# 933358        5  No Characteristic  All Appraisals           0   16.0
# 933361        5  No Characteristic  All Appraisals           0   21.0
# 933364        5  No Characteristic  All Appraisals           0   15.0
# 933367        5  No Characteristic  All Appraisals           0   26.0
# 933370        5  No Characteristic  All Appraisals           0   26.0

# %%
#Create columns for each series to act as a variable
fhfa_pivot_df = fhfa_LA_df.pivot(index=['FIPS', 'TRACT','YEAR'],
                    columns=['SERIES'],
                    values='VALUE').reset_index()
fhfa_pivot_df = fhfa_pivot_df[fhfa_pivot_df['YEAR']!=2022]
fhfa_pivot_df.TRACT = fhfa_pivot_df.TRACT.astype(np.int64)

# %%
fhfa_clean = fhfa_pivot_df.dropna()

# %% [markdown]
# ### NOLA Business Licenses Data
# #### The convert to FIPS ended up taking way too long.

# %%
# NOLA_df = pd.read_csv('https://data.nola.gov/api/views/hjcd-grvu/rows.csv?accessType=DOWNLOAD')

# %%
# NOLA_df.head()
# Out:
#                                         BusinessName  \
# 0                                            FACTUMS
# 1                                       AG 2018, LLC
# 2  ANNIE'S COMPLETE HOUSE CLEANING & JANITORIAL S...
# 3                                        A1 NEMT LLC
# 4                                          KAINTOCKS
#
#                                            OwnerName  \
# 0                           BULL INVESTIGATIONS, LLC
# 1                                       AG 2018, LLC
# 2  ANNIE'S COMPLETE HOUSE CLEANING & JANITORIAL S...
# 3                                        A1 NEMT LLC
# 4                             ODUM LANE VENTURES LLC
#
#                                   BusinessType  BusinessLicenseNumber  \
# 0                3801 - INVESTIGATION SERVICES                 291590
# 1      3309 - NONRESIDENTIAL PROPERTY MANAGERS                 293819
# 2                   2033 - JANITORIAL SERVICES                 293860
# 3          2032 - SPECIAL NEEDS TRANSPORTATION                 293822
# 4  1105 - FULL SVC RESTAURANTS (TABLE SERVICE)                 291807
#
#   BusinessStartDate                        Address StreetNumber  \
# 0        05/24/2021               6735 E HERMES ST         6735
# 1        12/14/2021  1626 ORETHA CASTLE HALEY BLVD         1626
# 2        10/07/2019                2139 HOLIDAY DR         2139
# 3        03/07/2019           6235 ST. ANTHONY AVE         6235
# 4        02/15/2022              735 ST. JOSEPH ST          735
#
#   StreetDirection           StreetName StreetSuffix  ...    Zip PhoneNumber  \
# 0               E               HERMES           ST  ...  70126  5044139958
# 1             NaN  ORETHA CASTLE HALEY         BLVD  ...  70113         NaN
# 2             NaN              HOLIDAY           DR  ...  70114         NaN
# 3             NaN          ST. ANTHONY          AVE  ...  70122         NaN
# 4             NaN           ST. JOSEPH           ST  ...  70130         NaN
#
#                      MailAddress MailSuite     MailCity MailState MailZip  \
# 0               6735 E HERMES ST       NaN  NEW ORLEANS        LA   70126
# 1  1626 ORETHA CASTLE HALEY BLVD       NaN  NEW ORLEANS        LA   70113
# 2                2139 HOLIDAY DR       NaN  NEW ORLEANS        LA   70114
# 3           6235 ST. ANTHONY AVE       NaN  NEW ORLEANS        LA   70122
# 4              735 ST. JOSEPH ST       NaN  NEW ORLEANS        LA   70130
#
#     Latitude  Longitude                               Location
# 0  30.023474 -90.015967  (30.0234737941083, -90.0159674788499)
# 1  29.939877 -90.079936   (29.9398769235327, -90.079936156175)
# 2  29.932313 -90.013698  (29.9323132108077, -90.0136980627568)
# 3        NaN        NaN                                    NaN
# 4        NaN        NaN                                    NaN
#
# [5 rows x 23 columns]

# %%
# #Extract year for aggregations
# from datetime import datetime

# def extract_year(date_string):
#     try:
#         # Parse the date string into a datetime object
#         date_obj = datetime.strptime(date_string, '%m/%d/%Y')
#         # Extract the year from the datetime object
#         year = date_obj.year
#         return year
#     except ValueError:
#         # Handle any invalid date strings or formatting errors
#         return None

# # Example usage
# NOLA_df['year'] = NOLA_df['BusinessStartDate'].apply(extract_year)
# NOLA_df.head()
# Out:
#                                         BusinessName  \
# 0                                            FACTUMS
# 1                                       AG 2018, LLC
# 2  ANNIE'S COMPLETE HOUSE CLEANING & JANITORIAL S...
# 3                                        A1 NEMT LLC
# 4                                          KAINTOCKS
#
#                                            OwnerName  \
# 0                           BULL INVESTIGATIONS, LLC
# 1                                       AG 2018, LLC
# 2  ANNIE'S COMPLETE HOUSE CLEANING & JANITORIAL S...
# 3                                        A1 NEMT LLC
# 4                             ODUM LANE VENTURES LLC
#
#                                   BusinessType  BusinessLicenseNumber  \
# 0                3801 - INVESTIGATION SERVICES                 291590
# 1      3309 - NONRESIDENTIAL PROPERTY MANAGERS                 293819
# 2                   2033 - JANITORIAL SERVICES                 293860
# 3          2032 - SPECIAL NEEDS TRANSPORTATION                 293822
# 4  1105 - FULL SVC RESTAURANTS (TABLE SERVICE)                 291807
#
#   BusinessStartDate                        Address StreetNumber  \
# 0        05/24/2021               6735 E HERMES ST         6735
# 1        12/14/2021  1626 ORETHA CASTLE HALEY BLVD         1626
# 2        10/07/2019                2139 HOLIDAY DR         2139
# 3        03/07/2019           6235 ST. ANTHONY AVE         6235
# 4        02/15/2022              735 ST. JOSEPH ST          735
#
#   StreetDirection           StreetName StreetSuffix  ... PhoneNumber  \
# 0               E               HERMES           ST  ...  5044139958
# 1             NaN  ORETHA CASTLE HALEY         BLVD  ...         NaN
# 2             NaN              HOLIDAY           DR  ...         NaN
# 3             NaN          ST. ANTHONY          AVE  ...         NaN
# 4             NaN           ST. JOSEPH           ST  ...         NaN
#
#                      MailAddress MailSuite     MailCity MailState MailZip  \
# 0               6735 E HERMES ST       NaN  NEW ORLEANS        LA   70126
# 1  1626 ORETHA CASTLE HALEY BLVD       NaN  NEW ORLEANS        LA   70113
# 2                2139 HOLIDAY DR       NaN  NEW ORLEANS        LA   70114
# 3           6235 ST. ANTHONY AVE       NaN  NEW ORLEANS        LA   70122
# 4              735 ST. JOSEPH ST       NaN  NEW ORLEANS        LA   70130
#
#     Latitude  Longitude                               Location  year
# 0  30.023474 -90.015967  (30.0234737941083, -90.0159674788499)  2021
# 1  29.939877 -90.079936   (29.9398769235327, -90.079936156175)  2021
# 2  29.932313 -90.013698  (29.9323132108077, -90.0136980627568)  2019
# 3        NaN        NaN                                    NaN  2019
# 4        NaN        NaN                                    NaN  2022
#
# [5 rows x 24 columns]

# %%
# NOLA_filtered = NOLA_df[(NOLA_df["year"] >= 2013) & (NOLA_df["year"] <= 2021)]
# NOLA_filtered
# Out:
#                                             BusinessName  \
# 0                                                FACTUMS
# 1                                           AG 2018, LLC
# 2      ANNIE'S COMPLETE HOUSE CLEANING & JANITORIAL S...
# 3                                            A1 NEMT LLC
# 6                                        SWEET DUPUY LLC
# ...                                                  ...
# 12002                       HOLLYWOOD CELEBRATION LOUNGE
# 12003                                  SAINT HUBERT INC.
# 12005                                    EVERSAINT SALON
# 12006                 BLUEGREEN RESORTS MANAGEMENT, INC.
# 12008                    COMFORT ENGINEERED SYSTEMS, INC
#
#                                                OwnerName  \
# 0                               BULL INVESTIGATIONS, LLC
# 1                                           AG 2018, LLC
# 2      ANNIE'S COMPLETE HOUSE CLEANING & JANITORIAL S...
# 3                                            A1 NEMT LLC
# 6                                        SWEET DUPUY LLC
# ...                                                  ...
# 12002                   HOLLYWOOD CELEBRATION LOUNGE LLC
# 12003                                  SAINT HUBERT INC.
# 12005                             ELEMENT BEAUTY BAR LLC
# 12006                 BLUEGREEN RESORTS MANAGEMENT, INC.
# 12008                    COMFORT ENGINEERED SYSTEMS, INC
#
#                                        BusinessType  BusinessLicenseNumber  \
# 0                     3801 - INVESTIGATION SERVICES                 291590
# 1           3309 - NONRESIDENTIAL PROPERTY MANAGERS                 293819
# 2                        2033 - JANITORIAL SERVICES                 293860
# 3               2032 - SPECIAL NEEDS TRANSPORTATION                 293822
# 6                   3203 - INTERIOR DESIGN SERVICES                 291765
# ...                                             ...                    ...
# 12002  1126 - DRINKING PLACES (ALCOHOLIC BEVERAGES)                 308022
# 12003  1160 - ELECTRONIC SHOPPING/MAIL-ORDER HOUSES                 308051
# 12005                          3338 - BEAUTY SALONS                 308023
# 12006  3305 - LESSOR OF RESIDENTIAL BLDGS/DWELLINGS                 308087
# 12008    0802 - PLUMBING, HEATING & A/C CONTRACTORS                 278647
#
#       BusinessStartDate                        Address StreetNumber  \
# 0            05/24/2021               6735 E HERMES ST         6735
# 1            12/14/2021  1626 ORETHA CASTLE HALEY BLVD         1626
# 2            10/07/2019                2139 HOLIDAY DR         2139
# 3            03/07/2019           6235 ST. ANTHONY AVE         6235
# 6            10/12/2016                1316 VALENCE ST         1316
# ...                 ...                            ...          ...
# 12002        05/16/2013           1535 N CLAIBORNE AVE         1535
# 12003        10/20/2016              1745 LAKESHORE DR         1745
# 12005        08/15/2019            1515 ST CHARLES AVE         1515
# 12006        04/23/2018                     144 ELK PL          144
# 12008        06/18/2013             5604 SALMEN STREER         5604
#
#       StreetDirection           StreetName StreetSuffix  ... PhoneNumber  \
# 0                   E               HERMES           ST  ...  5044139958
# 1                 NaN  ORETHA CASTLE HALEY         BLVD  ...         NaN
# 2                 NaN              HOLIDAY           DR  ...         NaN
# 3                 NaN          ST. ANTHONY          AVE  ...         NaN
# 6                 NaN              VALENCE           ST  ...         NaN
# ...               ...                  ...          ...  ...         ...
# 12002               N            CLAIBORNE          AVE  ...         NaN
# 12003             NaN            LAKESHORE           DR  ...         NaN
# 12005             NaN           ST CHARLES          AVE  ...         NaN
# 12006             NaN                  ELK           PL  ...         NaN
# 12008             NaN               SALMEN       STREER  ...  5046026648
#
#                          MailAddress MailSuite     MailCity MailState MailZip  \
# 0                   6735 E HERMES ST       NaN  NEW ORLEANS        LA   70126
# 1      1626 ORETHA CASTLE HALEY BLVD       NaN  NEW ORLEANS        LA   70113
# 2                    2139 HOLIDAY DR       NaN  NEW ORLEANS        LA   70114
# 3               6235 ST. ANTHONY AVE       NaN  NEW ORLEANS        LA   70122
# 6                    1316 VALENCE ST       NaN  NEW ORLEANS        LA   70115
# ...                              ...       ...          ...       ...     ...
# 12002                1221 N ROMAN ST       NaN  NEW ORLEANS        LA   70116
# 12003              1745 LAKESHORE DR       NaN  NEW ORLEANS        LA   70122
# 12005            1515 ST CHARLES AVE   STE 101  NEW ORLEANS        LA   70130
# 12006                     144 ELK PL       NaN  NEW ORLEANS        LA   70112
# 12008             5604 SALMEN STREER       NaN      HARAHAN        LA   70123
#
#         Latitude  Longitude                               Location  year
# 0      30.023474 -90.015967  (30.0234737941083, -90.0159674788499)  2021
# 1      29.939877 -90.079936   (29.9398769235327, -90.079936156175)  2021
# 2      29.932313 -90.013698  (29.9323132108077, -90.0136980627568)  2019
# 3            NaN        NaN                                    NaN  2019
# 6      29.924309 -90.105694  (29.9243091937069, -90.1056939504683)  2016
# ...          ...        ...                                    ...   ...
# 12002        NaN        NaN                                    NaN  2013
# 12003  30.030622 -90.076828  (30.0306218485828, -90.0768278605529)  2016
# 12005  29.938839 -90.075951  (29.9388391889167, -90.0759509099456)  2019
# 12006  29.955266 -90.073753     (29.95526621251, -90.073753361932)  2018
# 12008        NaN        NaN                                    NaN  2013
#
# [5608 rows x 24 columns]

# %%
# import requests

# def get_census_tract(row, api_key):
#     street_number = row["StreetNumber"]
#     street_name = row["StreetName"]
#     street_suffix = row["StreetSuffix"]
#     city = row["City"]
#     state = row["State"]
#     zip_code = row["Zip"]

#     address = f"{street_number} {street_name} {street_suffix}, {city}, {state} {zip_code}"

#     url = f"https://geocoding.geo.census.gov/geocoder/geographies/address?street={street_number}+{street_name}+{street_suffix}&city={city}&state={state}&zip={zip_code}&benchmark=Public_AR_Census2020&vintage=Census2020_Census2020&layers=8&format=json"
#     headers = {
#         "Accept": "application/json",
#         "Content-Type": "application/json",
#     }
#     # params = {
#     #     "key": census_key,
#     # }

#     response = requests.get(url, headers=headers, params=params)

#     if response.status_code == 200:
#         data = response.json()
#         address_matches = data.get("result", {}).get("addressMatches", [])
#         if address_matches:
#             census_tract = data["result"]["addressMatches"][0]["geographies"]["Census Block Groups"][0]["GEOID"]
#         else:
#             census_tract = "No Match"
#         return census_tract
#     else:
#         print("Error:", response.status_code)
#         return None

# # Example usage
# api_key = "YOUR_API_KEY"
# NOLA_filtered["census_tract"] = NOLA_filtered.apply(get_census_tract, api_key=census_key, axis=1)
# Out:
# BusinessName                                           FACTUMS
# OwnerName                             BULL INVESTIGATIONS, LLC
# BusinessType                     3801 - INVESTIGATION SERVICES
# BusinessLicenseNumber                                   291590
# BusinessStartDate                                   05/24/2021
# Address                                       6735 E HERMES ST
# StreetNumber                                              6735
# StreetDirection                                              E
# StreetName                                              HERMES
# StreetSuffix                                                ST
# Suite                                                      NaN
# City                                               NEW ORLEANS
# State                                                       LA
# Zip                                                      70126
# PhoneNumber                                         5044139958
# MailAddress                                   6735 E HERMES ST
# MailSuite                                                  NaN
# MailCity                                           NEW ORLEANS
# MailState                                                   LA
# MailZip                                                  70126
# Latitude                                             30.023474
# Longitude                                           -90.015967
# Location                 (30.0234737941083, -90.0159674788499)
# year                                                      2021
# Name: 0, dtype: object
# BusinessName                                        AG 2018, LLC
# OwnerName                                           AG 2018, LLC
# BusinessType             3309 - NONRESIDENTIAL PROPERTY MANAGERS
# BusinessLicenseNumber                                     293819
# BusinessStartDate                                     12/14/2021
# Address                            1626 ORETHA CASTLE HALEY BLVD
# StreetNumber                                                1626
# StreetDirection                                              NaN
# StreetName                                   ORETHA CASTLE HALEY
# StreetSuffix                                                BLVD
# Suite                                                        NaN
# City                                                 NEW ORLEANS
# State                                                         LA
# Zip                                                        70113
# PhoneNumber                                                  NaN
# MailAddress                        1626 ORETHA CASTLE HALEY BLVD
# MailSuite                                                    NaN
# MailCity                                             NEW ORLEANS
# MailState                                                     LA
# MailZip                                                    70113
# Latitude                                               29.939877
# Longitude                                             -90.079936
# Location                    (29.9398769235327, -90.079936156175)
# year                                                        2021
# Name: 1, dtype: object
# BusinessName             ANNIE'S COMPLETE HOUSE CLEANING & JANITORIAL S...
# OwnerName                ANNIE'S COMPLETE HOUSE CLEANING & JANITORIAL S...
# BusinessType                                    2033 - JANITORIAL SERVICES
# BusinessLicenseNumber                                               293860
# BusinessStartDate                                               10/07/2019
# Address                                                    2139 HOLIDAY DR
# StreetNumber                                                          2139
# StreetDirection                                                        NaN
# StreetName                                                         HOLIDAY
# StreetSuffix                                                            DR
# Suite                                                                  NaN
# City                                                           NEW ORLEANS
# State                                                                   LA
# Zip                                                                  70114
# PhoneNumber                                                            NaN
# MailAddress                                                2139 HOLIDAY DR
# MailSuite                                                              NaN
# MailCity                                                       NEW ORLEANS
# MailState                                                               LA
# MailZip                                                              70114
# Latitude                                                         29.932313
# Longitude                                                       -90.013698
# Location                             (29.9323132108077, -90.0136980627568)
# year                                                                  2019
# Name: 2, dtype: object
# BusinessName                                     A1 NEMT LLC
# OwnerName                                        A1 NEMT LLC
# BusinessType             2032 - SPECIAL NEEDS TRANSPORTATION
# BusinessLicenseNumber                                 293822
# BusinessStartDate                                 03/07/2019
# Address                                 6235 ST. ANTHONY AVE
# StreetNumber                                            6235
# StreetDirection                                          NaN
# StreetName                                       ST. ANTHONY
# StreetSuffix                                             AVE
# Suite                                                    NaN
# City                                             NEW ORLEANS
# State                                                     LA
# Zip                                                    70122
# PhoneNumber                                              NaN
# MailAddress                             6235 ST. ANTHONY AVE
# MailSuite                                                NaN
# MailCity                                         NEW ORLEANS
# MailState                                                 LA
# MailZip                                                70122
# Latitude                                                 NaN
# Longitude                                                NaN
# Location                                                 NaN
# year                                                    2019
# Name: 3, dtype: object
# BusinessName                                   SWEET DUPUY LLC
# OwnerName                                      SWEET DUPUY LLC
# BusinessType                   3203 - INTERIOR DESIGN SERVICES
# BusinessLicenseNumber                                   291765
# BusinessStartDate                                   10/12/2016
# Address                                        1316 VALENCE ST
# StreetNumber                                              1316
# StreetDirection                                            NaN
# StreetName                                             VALENCE
# StreetSuffix                                                ST
# Suite                                                      NaN
# City                                               NEW ORLEANS
# State                                                       LA
# Zip                                                      70115
# PhoneNumber                                                NaN
# MailAddress                                    1316 VALENCE ST
# MailSuite                                                  NaN
# MailCity                                           NEW ORLEANS
# MailState                                                   LA
# MailZip                                                  70115
# Latitude                                             29.924309
# Longitude                                           -90.105694
# Location                 (29.9243091937069, -90.1056939504683)
# year                                                      2016
# Name: 6, dtype: object
# BusinessName             NEW SAINT JOESPH COMUNITY DEVELOPMENT CORPORATION
# OwnerName                       NEW SAINT JOESPH MISSIONARY BAPTIST CHURCH
# BusinessType                   1401 - SOCIAL ADVOCACY ORGANIZATIONS, OTHER
# BusinessLicenseNumber                                               293824
# BusinessStartDate                                               03/27/2018
# Address                                                      3211 DIANA ST
# StreetNumber                                                          3211
# StreetDirection                                                        NaN
# StreetName                                                           DIANA
# StreetSuffix                                                            ST
# Suite                                                                  NaN
# City                                                           NEW ORLEANS
# State                                                                   LA
# Zip                                                                  70114
# PhoneNumber                                                            NaN
# MailAddress                                                  1100 ODEON ST
# MailSuite                                                              NaN
# MailCity                                                       NEW ORLEANS
# MailState                                                               LA
# MailZip                                                              70114
# Latitude                                                         29.943599
# Longitude                                                       -90.021711
# Location                             (29.9435994627791, -90.0217111173554)
# year                                                                  2018
# Name: 14, dtype: object
# BusinessName                               STATIONERY STYLIST
# OwnerName                              STATIONERY STYLIST LLC
# BusinessType                       3369 - GRAPHIC DESIGN SVCS
# BusinessLicenseNumber                                  293851
# BusinessStartDate                                  07/03/2018
# Address                                      2910 TOULOUSE ST
# StreetNumber                                             2910
# StreetDirection                                           NaN
# StreetName                                           TOULOUSE
# StreetSuffix                                               ST
# Suite                                                     NaN
# City                                              NEW ORLEANS
# State                                                      LA
# Zip                                                     70119
# PhoneNumber                                        5048107248
# MailAddress                                  2910 TOULOUSE ST
# MailSuite                                                 NaN
# MailCity                                          NEW ORLEANS
# MailState                                                  LA
# MailZip                                                 70119
# Latitude                                             29.97128
# Longitude                                          -90.086651
# Location                 (29.971280117487, -90.0866514345224)
# year                                                     2018
# Name: 16, dtype: object
# BusinessName                            AVENUE ART AND FRAMING
# OwnerName                               AVENUE ART AND FRAMING
# BusinessType                                1173 - ART DEALERS
# BusinessLicenseNumber                                   291649
# BusinessStartDate                                   04/21/2017
# Address                                       910 HARRISON AVE
# StreetNumber                                               910
# StreetDirection                                            NaN
# StreetName                                            HARRISON
# StreetSuffix                                               AVE
# Suite                                                      NaN
# City                                               NEW ORLEANS
# State                                                       LA
# Zip                                                      70124
# PhoneNumber                                       504 483 8901
# MailAddress                                   910 HARRISON AVE
# MailSuite                                                  NaN
# MailCity                                           NEW ORLEANS
# MailState                                                   LA
# MailZip                                                  70124
# Latitude                                             30.003874
# Longitude                                            -90.10339
# Location                 (30.0038744521236, -90.1033901994336)
# year                                                      2017
# Name: 17, dtype: object
# BusinessName                             THE COURTYARDS GUEST HOUSE
# OwnerName                                THE COURTYARDS GUEST HOUSE
# BusinessType             3308 - LESSORS OF OTH REAL ESTATE PROPERTY
# BusinessLicenseNumber                                        301441
# BusinessStartDate                                        07/31/2013
# Address                                               1428 ROYAL ST
# StreetNumber                                                   1428
# StreetDirection                                                 NaN
# StreetName                                                    ROYAL
# StreetSuffix                                                     ST
# Suite                                                           NaN
# City                                                    NEW ORLEANS
# State                                                            LA
# Zip                                                           70116
# PhoneNumber                                              5043739115
# MailAddress                                           1428 ROYAL ST
# MailSuite                                                       NaN
# MailCity                                                NEW ORLEANS
# MailState                                                        LA
# MailZip                                                       70116
# Latitude                                                  29.963899
# Longitude                                                -90.059348
# Location                      (29.9638987036972, -90.0593475805024)
# year                                                           2013
# Name: 20, dtype: object
# BusinessName                                       ENGINEERED SYSTEMS
# OwnerName                                          ENGINEERED SYSTEMS
# BusinessType             3315 - CONSUMER ELECTRONICS/APPLIANCE RENTAL
# BusinessLicenseNumber                                          291797
# BusinessStartDate                                          10/29/2021
# Address                                          6301 S ROCHEBLAVE ST
# StreetNumber                                                     6301
# StreetDirection                                                     S
# StreetName                                                 ROCHEBLAVE
# StreetSuffix                                                       ST
# Suite                                                             NaN
# City                                                      NEW ORLEANS
# State                                                              LA
# Zip                                                             70125
# PhoneNumber                                                       NaN
# MailAddress                                      6301 S ROCHEBLAVE ST
# MailSuite                                                         NaN
# MailCity                                                  NEW ORLEANS
# MailState                                                          LA
# MailZip                                                         70125
# Latitude                                                    29.948632
# Longitude                                                  -90.112768
# Location                         (29.9486322003331, -90.112767999644)
# year                                                             2021
# Name: 24, dtype: object
# BusinessName                     HERMANOS RIVERA CONSTRUCTION, LLC
# OwnerName                        HERMANOS RIVERA CONSTRUCTION, LLC
# BusinessType             3501 - SINGLE FAMILY HOUSING CONSTRUCTION
# BusinessLicenseNumber                                       292484
# BusinessStartDate                                       02/04/2020
# Address                                          5172 WICKFIELD DR
# StreetNumber                                                  5172
# StreetDirection                                                NaN
# StreetName                                               WICKFIELD
# StreetSuffix                                                    DR
# Suite                                                          NaN
# City                                                   NEW ORLEANS
# State                                                           LA
# Zip                                                          70122
# PhoneNumber                                                    NaN
# MailAddress                                      5172 WICKFIELD DR
# MailSuite                                                      NaN
# MailCity                                               NEW ORLEANS
# MailState                                                       LA
# MailZip                                                      70122
# Latitude                                                 30.010819
# Longitude                                               -90.068167
# Location                     (30.0108191435545, -90.0681665469614)
# year                                                          2020
# Name: 25, dtype: object
# BusinessName                                       KAMA SUTRA CABARET
# OwnerName                                 429 BOURBON HOSPITALITY LLC
# BusinessType             1126 - DRINKING PLACES (ALCOHOLIC BEVERAGES)
# BusinessLicenseNumber                                          291753
# BusinessStartDate                                          06/14/2017
# Address                                                433 BOURBON ST
# StreetNumber                                                      433
# StreetDirection                                                   NaN
# StreetName                                                    BOURBON
# StreetSuffix                                                       ST
# Suite                                                             NaN
# City                                                      NEW ORLEANS
# State                                                              LA
# Zip                                                             70130
# PhoneNumber                                                       NaN
# MailAddress                                               109 CAMP ST
# MailSuite                                                         NaN
# MailCity                                                  NEW ORLEANS
# MailState                                                          LA
# MailZip                                                         70130
# Latitude                                                    29.956871
# Longitude                                                   -90.06732
# Location                        (29.9568714729868, -90.0673197029905)
# year                                                             2017
# Name: 26, dtype: object
# BusinessName                                             MAIN SQUEEZE
# OwnerName                                                MAIN SQUEEZE
# BusinessType             2062 - LIMITED SVC RESTAURANTS(NO TABLE SVC)
# BusinessLicenseNumber                                          291755
# BusinessStartDate                                          05/17/2021
# Address                                              5808 MAGAZINE ST
# StreetNumber                                                     5808
# StreetDirection                                                   NaN
# StreetName                                                   MAGAZINE
# StreetSuffix                                                       ST
# Suite                                                             NaN
# City                                                      NEW ORLEANS
# State                                                              LA
# Zip                                                             70115
# PhoneNumber                                                       NaN
# MailAddress                                          5808 MAGAZINE ST
# MailSuite                                                         NaN
# MailCity                                                  NEW ORLEANS
# MailState                                                          LA
# MailZip                                                         70115
# Latitude                                                    29.921566
# Longitude                                                  -90.119483
# Location                         (29.921565732968, -90.1194832854474)
# year                                                             2021
# Name: 27, dtype: object
# BusinessName                                      JOAN MITCHELL CENTER
# OwnerName                                 JOAN MITCHELL FOUNDATION INC
# BusinessType             2052 - INDEPENDENT ARTISTS/WRITERS/PERFORMERS
# BusinessLicenseNumber                                           301110
# BusinessStartDate                                           01/04/2017
# Address                                           1464 N ROCHEBLAVE ST
# StreetNumber                                                      1464
# StreetDirection                                                      N
# StreetName                                                  ROCHEBLAVE
# StreetSuffix                                                        ST
# Suite                                                              NaN
# City                                                       NEW ORLEANS
# State                                                               LA
# Zip                                                             701199
# PhoneNumber                                                        NaN
# MailAddress                                       1464 N ROCHEBLAVE ST
# MailSuite                                                          NaN
# MailCity                                                   NEW ORLEANS
# MailState                                                           LA
# MailZip                                                         701199
# Latitude                                                      29.97502
# Longitude                                                   -90.074068
# Location                         (29.9750203573579, -90.0740682534709)
# year                                                              2017
# Name: 30, dtype: object
# BusinessName                                   THE ART GARDEN,
# OwnerName                                   THE ART GARDEN,LLC
# BusinessType                                1173 - ART DEALERS
# BusinessLicenseNumber                                   291817
# BusinessStartDate                                   12/09/2015
# Address                                       613 FRENCHMEN ST
# StreetNumber                                               613
# StreetDirection                                            NaN
# StreetName                                           FRENCHMEN
# StreetSuffix                                                ST
# Suite                                                      NaN
# City                                               NEW ORLEANS
# State                                                       LA
# Zip                                                      70116
# PhoneNumber                                                NaN
# MailAddress                                  3145 N RAMPART ST
# MailSuite                                                  NaN
# MailCity                                           NEW ORLEANS
# MailState                                                   LA
# MailZip                                                  70117
# Latitude                                             29.963893
# Longitude                                           -90.057692
# Location                 (29.9638928363772, -90.0576923203879)
# year                                                      2015
# Name: 31, dtype: object
# BusinessName                             CASEY DENSON LAW, LLC
# OwnerName                                CASEY DENSON LAW, LLC
# BusinessType                                    3382 - LAWYERS
# BusinessLicenseNumber                                   291759
# BusinessStartDate                                   11/19/2018
# Address                                       4911 MAGNOLIA ST
# StreetNumber                                              4911
# StreetDirection                                            NaN
# StreetName                                            MAGNOLIA
# StreetSuffix                                                ST
# Suite                                                      NaN
# City                                               NEW ORLEANS
# State                                                       LA
# Zip                                                      70115
# PhoneNumber                                                NaN
# MailAddress                                   4911 MAGNOLIA ST
# MailSuite                                                  NaN
# MailCity                                           NEW ORLEANS
# MailState                                                   LA
# MailZip                                                  70115
# Latitude                                             29.936972
# Longitude                                           -90.107491
# Location                 (29.9369723422426, -90.1074905624944)
# year                                                      2018
# Name: 32, dtype: object
# BusinessName                                       I GOT A GUY
# OwnerName                                             EFW1,LLC
# BusinessType                       2025 - LANDSCAPING SERVICES
# BusinessLicenseNumber                                   291764
# BusinessStartDate                                   10/01/2020
# Address                                          3111 CONTI ST
# StreetNumber                                              3111
# StreetDirection                                            NaN
# StreetName                                               CONTI
# StreetSuffix                                                ST
# Suite                                                      NaN
# City                                               NEW ORLEANS
# State                                                       LA
# Zip                                                      70119
# PhoneNumber                                                NaN
# MailAddress                                      3111 CONTI ST
# MailSuite                                                  NaN
# MailCity                                           NEW ORLEANS
# MailState                                                   LA
# MailZip                                                  70119
# Latitude                                             29.971074
# Longitude                                           -90.089272
# Location                 (29.9710741560063, -90.0892723023866)
# year                                                      2020
# Name: 33, dtype: object
# BusinessName                                           INKMULE
# OwnerName                                        LOGAN ROBERTS
# BusinessType                 0027 - COMMERCIAL SCREEN PRINTING
# BusinessLicenseNumber                                   291757
# BusinessStartDate                                   02/16/2014
# Address                      1915 MARTIN LUTHER KING, JR. BLVD
# StreetNumber                                              1915
# StreetDirection                                            NaN
# StreetName                             MARTIN LUTHER KING, JR.
# StreetSuffix                                              BLVD
# Suite                                                      1/2
# City                                               NEW ORLEANS
# State                                                       LA
# Zip                                                      70113
# PhoneNumber                                                NaN
# MailAddress                  1915 MARTIN LUTHER KING, JR. BLVD
# MailSuite                                                  1/2
# MailCity                                           NEW ORLEANS
# MailState                                                   LA
# MailZip                                                  70113
# Latitude                                             29.941542
# Longitude                                           -90.079466
# Location                 (29.9415419187326, -90.0794655150276)
# year                                                      2014
# Name: 35, dtype: object
# BusinessName                           OCH REDEVELOPMENT PARTNERS LLC
# OwnerName                              OCH REDEVELOPMENT PARTNERS LLC
# BusinessType             3305 - LESSOR OF RESIDENTIAL BLDGS/DWELLINGS
# BusinessLicenseNumber                                          291810
# BusinessStartDate                                          07/23/2019
# Address                                               2600 GRAVIER ST
# StreetNumber                                                     2600
# StreetDirection                                                   NaN
# StreetName                                                    GRAVIER
# StreetSuffix                                                       ST
# Suite                                                             NaN
# City                                                      NEW ORLEANS
# State                                                              LA
# Zip                                                             70119
# PhoneNumber                                                       NaN
# MailAddress                                               803 PINE ST
# MailSuite                                                         NaN
# MailCity                                                  NEW ORLEANS
# MailState                                                          LA
# MailZip                                                         70118
# Latitude                                                    29.959929
# Longitude                                                  -90.090243
# Location                        (29.9599294584612, -90.0902427316775)
# year                                                             2019
# Name: 37, dtype: object
# BusinessName                             FOOTPRINTS TO FITNESS
# OwnerName                            FOOTPRINTS TO FITNESS,LLC
# BusinessType               3803 - PERSONAL SERVICES, ALL OTHER
# BusinessLicenseNumber                                   291791
# BusinessStartDate                                   09/21/2016
# Address                                      1001 HARRISON AVE
# StreetNumber                                              1001
# StreetDirection                                            NaN
# StreetName                                            HARRISON
# StreetSuffix                                               AVE
# Suite                                                      NaN
# City                                               NEW ORLEANS
# State                                                       LA
# Zip                                                      70124
# PhoneNumber                                                NaN
# MailAddress                                  1001 HARRISON AVE
# MailSuite                                                  NaN
# MailCity                                           NEW ORLEANS
# MailState                                                   LA
# MailZip                                                  70124
# Latitude                                             30.004289
# Longitude                                           -90.099426
# Location                 (30.0042888786853, -90.0994261531127)
# year                                                      2016
# Name: 38, dtype: object
# BusinessName                     HILTON GARDEN INN FRENCH QUATER/CBD
# OwnerName                                   MHF NOLA MANAGER VI, LLC
# BusinessType             1105 - FULL SVC RESTAURANTS (TABLE SERVICE)
# BusinessLicenseNumber                                         291781
# BusinessStartDate                                         10/09/2019
# Address                                               821 GRAVIER ST
# StreetNumber                                                     821
# StreetDirection                                                  NaN
# StreetName                                                   GRAVIER
# StreetSuffix                                                      ST
# Suite                                                            NaN
# City                                                     NEW ORLEANS
# State                                                             LA
# Zip                                                            70112
# PhoneNumber                                                      NaN
# MailAddress                                        610 SMITHFIELD ST
# MailSuite                                                        300
# MailCity                                                  PITTSBURGH
# MailState                                                         PA
# MailZip                                                        15222
# Latitude                                                   29.952321
# Longitude                                                  -90.07187
# Location                       (29.9523210422171, -90.0718696042826)
# year                                                            2019
# Name: 39, dtype: object
# BusinessName                                         DAVE & BUSTER'S
# OwnerName                         DAVE & BUSTER'S OF LOUISIANA, INC.
# BusinessType             1105 - FULL SVC RESTAURANTS (TABLE SERVICE)
# BusinessLicenseNumber                                         283712
# BusinessStartDate                                         05/22/2017
# Address                                              1200 POYDRAS ST
# StreetNumber                                                    1200
# StreetDirection                                                  NaN
# StreetName                                                   POYDRAS
# StreetSuffix                                                      ST
# Suite                                                       UNIT 601
# City                                                     NEW ORLEANS
# State                                                             LA
# Zip                                                            70113
# PhoneNumber                                               9728131142
# MailAddress                                           2481 MANANA DR
# MailSuite                                                        NaN
# MailCity                                                      DALLAS
# MailState                                                         TX
# MailZip                                                        75220
# Latitude                                                   29.950573
# Longitude                                                 -90.076323
# Location                       (29.9505732310622, -90.0763232703719)
# year                                                            2017
# Name: 40, dtype: object
# BusinessName                              ROAD TRIP COLLECTION
# OwnerName                             ROAD TRIP COLLECTION,LLC
# BusinessType               3803 - PERSONAL SERVICES, ALL OTHER
# BusinessLicenseNumber                                   306626
# BusinessStartDate                                   06/01/2021
# Address                                        932 AMETHYST ST
# StreetNumber                                               932
# StreetDirection                                            NaN
# StreetName                                            AMETHYST
# StreetSuffix                                                ST
# Suite                                                      NaN
# City                                               NEW ORLEANS
# State                                                       LA
# Zip                                                      70124
# PhoneNumber                                                NaN
# MailAddress                                    932 AMETHYST ST
# MailSuite                                                  NaN
# MailCity                                           NEW ORLEANS
# MailState                                                   LA
# MailZip                                                  70124
# Latitude                                             30.026133
# Longitude                                           -90.100528
# Location                 (30.0261326603506, -90.1005283382839)
# year                                                      2021
# Name: 41, dtype: object
# BusinessName                                      MKM SAFETY PARTNERS
# OwnerName                                         MKM SAFETY PARTNERS
# BusinessType             4201 - SCIENTIFIC/TECHNCL CONSLTNG SVCS, OTH
# BusinessLicenseNumber                                          289635
# BusinessStartDate                                          10/17/2021
# Address                                                8236 PANOLA ST
# StreetNumber                                                     8236
# StreetDirection                                                   NaN
# StreetName                                                     PANOLA
# StreetSuffix                                                       ST
# Suite                                                             NaN
# City                                                      NEW ORLEANS
# State                                                              LA
# Zip                                                             70118
# PhoneNumber                                                       NaN
# MailAddress                                            8236 PANOLA ST
# MailSuite                                                         NaN
# MailCity                                                  NEW ORLEANS
# MailState                                                          LA
# MailZip                                                         70118
# Latitude                                                    29.954921
# Longitude                                                  -90.124627
# Location                        (29.9549211934952, -90.1246274139309)
# year                                                             2021
# Name: 45, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [155], in <cell line: 39>()
#      37 # Example usage
#      38 api_key = "YOUR_API_KEY"
# ---> 39 NOLA_filtered["census_tract"] = NOLA_filtered.apply(get_census_tract, api_key=census_key, axis=1)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:8845, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8834 from pandas.core.apply import frame_apply
#    8836 op = frame_apply(
#    8837     self,
#    8838     func=func,
#    (...)
#    8843     kwargs=kwargs,
#    8844 )
# -> 8845 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\apply.py:733, in FrameApply.apply(self)
#     730 elif self.raw:
#     731     return self.apply_raw()
# --> 733 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\apply.py:857, in FrameApply.apply_standard(self)
#     856 def apply_standard(self):
# --> 857     results, res_index = self.apply_series_generator()
#     859     # wrap results
#     860     return self.wrap_results(results, res_index)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\apply.py:873, in FrameApply.apply_series_generator(self)
#     870 with option_context("mode.chained_assignment", None):
#     871     for i, v in enumerate(series_gen):
#     872         # ignore SettingWithCopy here in case the user mutates
# --> 873         results[i] = self.f(v)
#     874         if isinstance(results[i], ABCSeries):
#     875             # If we have a view on v, we need to make a copy because
#     876             #  series_generator will swap out the underlying data
#     877             results[i] = results[i].copy(deep=False)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\apply.py:138, in Apply.__init__.<locals>.f(x)
#     137 def f(x):
# --> 138     return func(x, *args, **kwargs)
#
# Input In [155], in get_census_tract(row, api_key)
#      14 headers = {
#      15     "Accept": "application/json",
#      16     "Content-Type": "application/json",
#      17 }
#      18 # params = {
#      19 #     "key": census_key,
#      20 # }
# ---> 22 response = requests.get(url, headers=headers, params=params)
#      24 if response.status_code == 200:
#      25     data = response.json()
#
# File ~\anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1038 # Force connect early to allow us to validate the connection.
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#    1043     warnings.warn(
#    1044         (
#    1045             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1050         InsecureRequestWarning,
#    1051     )
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#     360     tls_in_tls = False
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:

# %%
NOLA_filtered
# Out:
#                                             BusinessName  \
# 0                                                FACTUMS
# 1                                           AG 2018, LLC
# 2      ANNIE'S COMPLETE HOUSE CLEANING & JANITORIAL S...
# 3                                            A1 NEMT LLC
# 6                                        SWEET DUPUY LLC
# ...                                                  ...
# 12002                       HOLLYWOOD CELEBRATION LOUNGE
# 12003                                  SAINT HUBERT INC.
# 12005                                    EVERSAINT SALON
# 12006                 BLUEGREEN RESORTS MANAGEMENT, INC.
# 12008                    COMFORT ENGINEERED SYSTEMS, INC
#
#                                                OwnerName  \
# 0                               BULL INVESTIGATIONS, LLC
# 1                                           AG 2018, LLC
# 2      ANNIE'S COMPLETE HOUSE CLEANING & JANITORIAL S...
# 3                                            A1 NEMT LLC
# 6                                        SWEET DUPUY LLC
# ...                                                  ...
# 12002                   HOLLYWOOD CELEBRATION LOUNGE LLC
# 12003                                  SAINT HUBERT INC.
# 12005                             ELEMENT BEAUTY BAR LLC
# 12006                 BLUEGREEN RESORTS MANAGEMENT, INC.
# 12008                    COMFORT ENGINEERED SYSTEMS, INC
#
#                                        BusinessType  BusinessLicenseNumber  \
# 0                     3801 - INVESTIGATION SERVICES                 291590
# 1           3309 - NONRESIDENTIAL PROPERTY MANAGERS                 293819
# 2                        2033 - JANITORIAL SERVICES                 293860
# 3               2032 - SPECIAL NEEDS TRANSPORTATION                 293822
# 6                   3203 - INTERIOR DESIGN SERVICES                 291765
# ...                                             ...                    ...
# 12002  1126 - DRINKING PLACES (ALCOHOLIC BEVERAGES)                 308022
# 12003  1160 - ELECTRONIC SHOPPING/MAIL-ORDER HOUSES                 308051
# 12005                          3338 - BEAUTY SALONS                 308023
# 12006  3305 - LESSOR OF RESIDENTIAL BLDGS/DWELLINGS                 308087
# 12008    0802 - PLUMBING, HEATING & A/C CONTRACTORS                 278647
#
#       BusinessStartDate                        Address StreetNumber  \
# 0            05/24/2021               6735 E HERMES ST         6735
# 1            12/14/2021  1626 ORETHA CASTLE HALEY BLVD         1626
# 2            10/07/2019                2139 HOLIDAY DR         2139
# 3            03/07/2019           6235 ST. ANTHONY AVE         6235
# 6            10/12/2016                1316 VALENCE ST         1316
# ...                 ...                            ...          ...
# 12002        05/16/2013           1535 N CLAIBORNE AVE         1535
# 12003        10/20/2016              1745 LAKESHORE DR         1745
# 12005        08/15/2019            1515 ST CHARLES AVE         1515
# 12006        04/23/2018                     144 ELK PL          144
# 12008        06/18/2013             5604 SALMEN STREER         5604
#
#       StreetDirection           StreetName StreetSuffix  ... PhoneNumber  \
# 0                   E               HERMES           ST  ...  5044139958
# 1                 NaN  ORETHA CASTLE HALEY         BLVD  ...         NaN
# 2                 NaN              HOLIDAY           DR  ...         NaN
# 3                 NaN          ST. ANTHONY          AVE  ...         NaN
# 6                 NaN              VALENCE           ST  ...         NaN
# ...               ...                  ...          ...  ...         ...
# 12002               N            CLAIBORNE          AVE  ...         NaN
# 12003             NaN            LAKESHORE           DR  ...         NaN
# 12005             NaN           ST CHARLES          AVE  ...         NaN
# 12006             NaN                  ELK           PL  ...         NaN
# 12008             NaN               SALMEN       STREER  ...  5046026648
#
#                          MailAddress MailSuite     MailCity MailState MailZip  \
# 0                   6735 E HERMES ST       NaN  NEW ORLEANS        LA   70126
# 1      1626 ORETHA CASTLE HALEY BLVD       NaN  NEW ORLEANS        LA   70113
# 2                    2139 HOLIDAY DR       NaN  NEW ORLEANS        LA   70114
# 3               6235 ST. ANTHONY AVE       NaN  NEW ORLEANS        LA   70122
# 6                    1316 VALENCE ST       NaN  NEW ORLEANS        LA   70115
# ...                              ...       ...          ...       ...     ...
# 12002                1221 N ROMAN ST       NaN  NEW ORLEANS        LA   70116
# 12003              1745 LAKESHORE DR       NaN  NEW ORLEANS        LA   70122
# 12005            1515 ST CHARLES AVE   STE 101  NEW ORLEANS        LA   70130
# 12006                     144 ELK PL       NaN  NEW ORLEANS        LA   70112
# 12008             5604 SALMEN STREER       NaN      HARAHAN        LA   70123
#
#         Latitude  Longitude                               Location  year
# 0      30.023474 -90.015967  (30.0234737941083, -90.0159674788499)  2021
# 1      29.939877 -90.079936   (29.9398769235327, -90.079936156175)  2021
# 2      29.932313 -90.013698  (29.9323132108077, -90.0136980627568)  2019
# 3            NaN        NaN                                    NaN  2019
# 6      29.924309 -90.105694  (29.9243091937069, -90.1056939504683)  2016
# ...          ...        ...                                    ...   ...
# 12002        NaN        NaN                                    NaN  2013
# 12003  30.030622 -90.076828  (30.0306218485828, -90.0768278605529)  2016
# 12005  29.938839 -90.075951  (29.9388391889167, -90.0759509099456)  2019
# 12006  29.955266 -90.073753     (29.95526621251, -90.073753361932)  2018
# 12008        NaN        NaN                                    NaN  2013
#
# [5608 rows x 24 columns]

# %% [markdown]
# ### Zillow Data
# #### I'm going to use the ZHVI to see if the difference from the median house value to the ZHVI will increase preditive accuracy.

# %%
url = 'https://files.zillowstatic.com/research/public_csvs/zhvi/County_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv?t=1684739249'
zillow_df = pd.read_csv(url)

# %%
zillow_df.head()
# Out:
#    RegionID  SizeRank          RegionName RegionType StateName State  \
# 0      3101         0  Los Angeles County     county        CA    CA
# 1       139         1         Cook County     county        IL    IL
# 2      1090         2       Harris County     county        TX    TX
# 3      2402         3     Maricopa County     county        AZ    AZ
# 4      2841         4    San Diego County     county        CA    CA
#
#                                   Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0    Los Angeles-Long Beach-Anaheim, CA              6                 37
# 1    Chicago-Naperville-Elgin, IL-IN-WI             17                 31
# 2  Houston-The Woodlands-Sugar Land, TX             48                201
# 3             Phoenix-Mesa-Chandler, AZ              4                 13
# 4    San Diego-Chula Vista-Carlsbad, CA              6                 73
#
#       2000-01-31  ...     2022-07-31     2022-08-31     2022-09-30  \
# 0  208469.545294  ...  860194.125359  858699.694776  855108.149163
# 1  135209.743813  ...  287833.656571  286479.197849  284349.306082
# 2  107803.585034  ...  284216.691741  285439.730049  285470.167172
# 3  144216.554561  ...  480491.129894  480029.852101  475629.544967
# 4  215557.171867  ...  905710.716610  898359.973900  886216.965364
#
#       2022-10-31     2022-11-30     2022-12-31     2023-01-31     2023-02-28  \
# 0  851292.909154  848758.281718  845453.621302  838059.913020  828052.150813
# 1  282557.706686  281757.297709  280995.357778  281623.651834  282378.213360
# 2  285065.699920  284585.908859  283423.404229  281696.493625  280127.611574
# 3  469875.637125  463618.859924  456960.880046  451584.197172  447662.124182
# 4  875189.704464  866753.101029  859458.558851  852409.382100  847776.745169
#
#       2023-03-31     2023-04-30
# 0  819773.212443  815928.037995
# 1  283706.876634  284464.296826
# 2  279535.622215  279462.819123
# 3  446135.264108  445142.630588
# 4  847358.903493  850394.864590
#
# [5 rows x 289 columns]

# %%
zillow_df2 = zillow_df[(zillow_df['Metro']=='New Orleans-Metairie, LA')&(zillow_df['MunicipalCodeFIPS']==71)]
zillow_df2.head()

# %%
#Range of columns to melt
date_cols = zillow_df2.columns[9:]
date_cols
# Out:
# Index(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30', '2000-05-31',
#        '2000-06-30', '2000-07-31', '2000-08-31', '2000-09-30', '2000-10-31',
#        ...
#        '2022-07-31', '2022-08-31', '2022-09-30', '2022-10-31', '2022-11-30',
#        '2022-12-31', '2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30'],
#       dtype='object', length=280)

# %%
#Move the months to their own row.
zillow_melted = pd.melt(zillow_df2, id_vars = 'MunicipalCodeFIPS', value_vars = date_cols, var_name='date', value_name='zhvi')
zillow_melted.head(1)
# Out:
#    MunicipalCodeFIPS        date          zhvi
# 0                 71  2000-01-31  91782.759189

# %%
zillow_melted['date'] = pd.to_datetime(zillow_melted['date'])

# %%
# Group by year and calculate the average
zhvi_avg = zillow_melted.groupby(zillow_melted['date'].dt.year)['zhvi'].mean().reset_index()
zhvi_clean = zhvi_avg[zhvi_avg['date']>2012]
zhvi_clean = zhvi_clean.rename(columns={'date':'year'})

# Print the average values by year
print(zhvi_clean)
# Out:
#     year           zhvi
# 13  2013  140626.587803
# 14  2014  150538.200408
# 15  2015  164244.466053
# 16  2016  182126.404887
# 17  2017  184262.007452
# 18  2018  188764.322559
# 19  2019  208431.062201
# 20  2020  226043.058024
# 21  2021  251027.306379
# 22  2022  275290.824039
# 23  2023  266967.806212

# %% [markdown]
# ### Merge Dataframes

# %%
merged_df = pd.merge(census_df2, fhfa_clean, left_on = ['TRACT','year'], right_on = ['TRACT', 'YEAR'])

# %%
merged_df.head()
# Out:
#    median_income  median_rent  total_pop  male_white_20_24  male_white_25_29  \
# 0          86182         1023       1904                15               101
# 1          51477          971       1675                32                98
# 2          65236         1271       2120                45               144
# 3          46875         1011       1232                14                34
# 4          81406         1433       1315                48                33
#
#    male_white_30_34  female_white_20_24  female_white_25_29  \
# 0                35                  23                  49
# 1                12                 127                  47
# 2                95                  63                 176
# 3                62                   3                  64
# 4                85                  49                  91
#
#    female_white_30_34  year  prop_white_20_34        TRACT   FIPS  YEAR  \
# 0                  44  2013          0.140231  22071009000  22071  2013
# 1                  80  2013          0.236418  22071009600  22071  2013
# 2                  53  2013          0.271698  22071010100  22071  2013
# 3                  57  2013          0.189935  22071010600  22071  2013
# 4                  38  2013          0.261597  22071011500  22071  2013
#
#    25% Quartile of Appraised Value  75% Quartile of Appraised Value  \
# 0                         525000.0                        1375000.0
# 1                         340000.0                         450000.0
# 2                         357000.0                         680000.0
# 3                         283000.0                         530000.0
# 4                         575000.0                         890000.0
#
#    Count of Appraisals  Mean Appraised Value  Median Appraised Value
# 0                 29.0              929000.0                725000.0
# 1                 46.0              403500.0                395500.0
# 2                 26.0              535700.0                487500.0
# 3                 31.0              396400.0                350000.0
# 4                 36.0              777700.0                690000.0

# %%
merged_df2 = pd.merge(merged_df, zhvi_clean, on='year')

# %%
merged_df2
# Out:
#       median_income  median_rent  total_pop  male_white_20_24  \
# 0             86182         1023       1904                15
# 1             51477          971       1675                32
# 2             65236         1271       2120                45
# 3             46875         1011       1232                14
# 4             81406         1433       1315                48
# ...             ...          ...        ...               ...
# 997           74695         1276       1103                 2
# 998           26683          879       2711                 0
# 999           45119          888       1608                 0
# 1000          99063         1347       1748                 2
# 1001          88992         1315       1583                 8
#
#       male_white_25_29  male_white_30_34  female_white_20_24  \
# 0                  101                35                  23
# 1                   98                12                 127
# 2                  144                95                  63
# 3                   34                62                   3
# 4                   33                85                  49
# ...                ...               ...                 ...
# 997                  4                18                   5
# 998                  4                 0                   0
# 999                 25                 7                   9
# 1000                20                41                   3
# 1001                25                79                   2
#
#       female_white_25_29  female_white_30_34  year  prop_white_20_34  \
# 0                     49                  44  2013          0.140231
# 1                     47                  80  2013          0.236418
# 2                    176                  53  2013          0.271698
# 3                     64                  57  2013          0.189935
# 4                     91                  38  2013          0.261597
# ...                  ...                 ...   ...               ...
# 997                    9                  45  2021          0.075249
# 998                    2                   0  2021          0.002213
# 999                    5                   0  2021          0.028607
# 1000                  70                  99  2021          0.134439
# 1001                  38                  88  2021          0.151611
#
#             TRACT   FIPS  YEAR  25% Quartile of Appraised Value  \
# 0     22071009000  22071  2013                         525000.0
# 1     22071009600  22071  2013                         340000.0
# 2     22071010100  22071  2013                         357000.0
# 3     22071010600  22071  2013                         283000.0
# 4     22071011500  22071  2013                         575000.0
# ...           ...    ...   ...                              ...
# 997   22071013600  22071  2021                         325000.0
# 998   22071013800  22071  2021                         189000.0
# 999   22071014101  22071  2021                         353000.0
# 1000  22071014200  22071  2021                         445000.0
# 1001  22071014400  22071  2021                         587500.0
#
#       75% Quartile of Appraised Value  Count of Appraisals  \
# 0                           1375000.0                 29.0
# 1                            450000.0                 46.0
# 2                            680000.0                 26.0
# 3                            530000.0                 31.0
# 4                            890000.0                 36.0
# ...                               ...                  ...
# 997                          525000.0                 17.0
# 998                          338000.0                 19.0
# 999                          585000.0                 23.0
# 1000                         665000.0                 62.0
# 1001                        1012000.0                 32.0
#
#       Mean Appraised Value  Median Appraised Value           zhvi
# 0                 929000.0                725000.0  140626.587803
# 1                 403500.0                395500.0  140626.587803
# 2                 535700.0                487500.0  140626.587803
# 3                 396400.0                350000.0  140626.587803
# 4                 777700.0                690000.0  140626.587803
# ...                    ...                     ...            ...
# 997               428100.0                440000.0  251027.306379
# 998               292700.0                300000.0  251027.306379
# 999               482100.0                474000.0  251027.306379
# 1000              588500.0                582000.0  251027.306379
# 1001              795700.0                741000.0  251027.306379
#
# [1002 rows x 20 columns]

# %% [markdown]
# ### Plotting

# %%
# Read the shapefile for New Orleans tracts
shapefile_path = 'tl_rd22_22071_faces.shp'
tracts_gdf = gpd.read_file(shapefile_path)
tracts_gdf
# Out:
#             TFID STATEFP20 COUNTYFP20 TRACTCE20 BLKGRPCE20 BLOCKCE20  \
# 0      260383227        22        071    003308          3      3004
# 1      260762213        22        071    003308          3      3000
# 2      260383235        22        071    003308          3      3002
# 3      260383239        22        071    003308          3      3001
# 4      266058279        22        071    002300          1      1027
# ...          ...       ...        ...       ...        ...       ...
# 16519  267942294        22        071    008400          2      2006
# 16520  267942298        22        071    009000          1      1005
# 16521  267942300        22        071    013501          1      1002
# 16522  267942302        22        071    011600          2      2012
# 16523  267942305        22        071    011600          2      2005
#
#        SUFFIX1CE ZCTA5CE20 UACE20 PUMACE20  ... METDIVFP CNECTAFP NECTAFP  \
# 0            NaN     70122  62677    02401  ...      NaN      NaN     NaN
# 1            NaN     70122  62677    02401  ...      NaN      NaN     NaN
# 2            NaN     70122  62677    02401  ...      NaN      NaN     NaN
# 3            NaN     70122  62677    02401  ...      NaN      NaN     NaN
# 4            NaN     70117  62677    02402  ...      NaN      NaN     NaN
# ...          ...       ...    ...      ...  ...      ...      ...     ...
# 16519        NaN     70113  62677    02402  ...      NaN      NaN     NaN
# 16520        NaN     70115  62677    02403  ...      NaN      NaN     NaN
# 16521        NaN     70116  62677    02403  ...      NaN      NaN     NaN
# 16522        NaN     70118  62677    02403  ...      NaN      NaN     NaN
# 16523        NaN     70118  62677    02403  ...      NaN      NaN     NaN
#
#       NCTADVFP LWFLAG  OFFSET  ATOTAL     INTPTLAT     INTPTLON  \
# 0          NaN      L       N   22648  +29.9935222  -90.0676062
# 1          NaN      L       N   28114  +29.9991398  -90.0655345
# 2          NaN      L       N   42106  +29.9975219  -90.0677972
# 3          NaN      L       N   51454  +29.9964317  -90.0636121
# 4          NaN      L       N     611  +29.9849761  -90.0581465
# ...        ...    ...     ...     ...          ...          ...
# 16519      NaN      L       N    7905  +29.9349862  -90.0824474
# 16520      NaN      L       N    8223  +29.9300233  -90.0858425
# 16521      NaN      L       N    3144  +29.9599796  -90.0679861
# 16522      NaN      L       N    5101  +29.9243180  -90.1204017
# 16523      NaN      L       N    5030  +29.9252094  -90.1200612
#
#                                                 geometry
# 0      POLYGON ((-90.06828 29.99423, -90.06777 29.994...
# 1      POLYGON ((-90.06834 29.99948, -90.06712 30.000...
# 2      POLYGON ((-90.06824 29.99937, -90.06647 29.997...
# 3      POLYGON ((-90.06538 29.99681, -90.06497 29.997...
# 4      POLYGON ((-90.05823 29.98521, -90.05819 29.985...
# ...                                                  ...
# 16519  POLYGON ((-90.08327 29.93473, -90.08228 29.935...
# 16520  POLYGON ((-90.08615 29.93075, -90.08583 29.930...
# 16521  POLYGON ((-90.06824 29.96034, -90.06757 29.959...
# 16522  POLYGON ((-90.12046 29.92480, -90.12000 29.924...
# 16523  POLYGON ((-90.12013 29.92573, -90.11965 29.925...
#
# [16524 rows x 45 columns]

# %%
#tracts_gdf.TRACTCE20 = tracts_gdf.TRACTCE20.astype(np.int64)
# Merge census data with the geospatial data
merged_gdf = tracts_gdf.merge(merged_df, left_on='TRACTCE20', right_on='TRACT', how='left')

merged_gdf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [103], in <cell line: 3>()
#       1 #tracts_gdf.TRACTCE20 = tracts_gdf.TRACTCE20.astype(np.int64)
#       2 # Merge census data with the geospatial data
# ----> 3 merged_gdf = tracts_gdf.merge(merged_df, left_on='TRACTCE20', right_on='TRACT', how='left')
#       5 merged_gdf
#
# File ~\anaconda3\lib\site-packages\geopandas\geodataframe.py:1569, in GeoDataFrame.merge(self, *args, **kwargs)
#    1551 def merge(self, *args, **kwargs):
#    1552     r"""Merge two ``GeoDataFrame`` objects with a database-style join.
#    1553
#    1554     Returns a ``GeoDataFrame`` if a geometry column is present; otherwise,
#    (...)
#    1567     for more details.
#    1568     """
# -> 1569     result = DataFrame.merge(self, *args, **kwargs)
#    1570     geo_col = self._geometry_column_name
#    1571     if isinstance(result, DataFrame) and geo_col in result:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:9351, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9332 @Substitution("")
#    9333 @Appender(_merge_doc, indents=2)
#    9334 def merge(
#    (...)
#    9347     validate: str | None = None,
#    9348 ) -> DataFrame:
#    9349     from pandas.core.reshape.merge import merge
# -> 9351     return merge(
#    9352         self,
#    9353         right,
#    9354         how=how,
#    9355         on=on,
#    9356         left_on=left_on,
#    9357         right_on=right_on,
#    9358         left_index=left_index,
#    9359         right_index=right_index,
#    9360         sort=sort,
#    9361         suffixes=suffixes,
#    9362         copy=copy,
#    9363         indicator=indicator,
#    9364         validate=validate,
#    9365     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py:704, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
#     700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
# --> 704 self._maybe_coerce_merge_keys()
#     706 # If argument passed to validate,
#     707 # check if columns specified as unique
#     708 # are in fact unique.
#     709 if validate is not None:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py:1261, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1255     # unless we are merging non-string-like with string-like
#    1256     elif (
#    1257         inferred_left in string_types and inferred_right not in string_types
#    1258     ) or (
#    1259         inferred_right in string_types and inferred_left not in string_types
#    1260     ):
# -> 1261         raise ValueError(msg)
#    1263 # datetimelikes must match exactly
#    1264 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
#plot
fig, ax = plt.subplots(1, figsize=(8, 8))
plt.xticks(rotation=90)

merged_gdf.plot(column="prop_white_20_34", cmap="Reds", linewidth=0.4, 
                   ax=ax, edgecolor=".4")
bar_info = plt.cm.ScalarMappable(cmap="Reds", norm=plt.Normalize(vmin=0, vmax=100))
bar_info._A = []
cbar = fig.colorbar(bar_info)
